# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data=pd.read_csv('../output/cleaned_hm.csv')

# %%
data.head()
# Out:
#     hmid   wid reflection_period  \
# 0  27673  2053               24h
# 1  27674     2               24h
# 2  27675  1936               24h
# 3  27676   206               24h
# 4  27677  6227               24h
#
#                                          original_hm  \
# 0  I went on a successful date with someone I fel...
# 1  I was happy when my son got 90% marks in his e...
# 2       I went to the gym this morning and did yoga.
# 3  We had a serious talk with some friends of our...
# 4  I went with grandchildren to butterfly display...
#
#                                           cleaned_hm  modified  num_sentence  \
# 0  I went on a successful date with someone I fel...      True             1
# 1  I was happy when my son got 90% marks in his e...      True             1
# 2       I went to the gym this morning and did yoga.      True             1
# 3  We had a serious talk with some friends of our...      True             2
# 4  I went with grandchildren to butterfly display...      True             1
#
#   ground_truth_category predicted_category
# 0                   NaN          affection
# 1                   NaN          affection
# 2                   NaN           exercise
# 3               bonding            bonding
# 4                   NaN          affection

# %%
import nltk
from nltk.corpus import brown
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
import re

# %%
from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer
import string
nltk.download("stopwords")
nltk.download("wordnet")
stop = set(stopwords.words('english'))
exclude = set(string.punctuation) 
lemma = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/chenxishi/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/chenxishi/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
def clean(doc):
    stop_free = " ".join([i for i in doc.lower().split() if i not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    number_free = "".join(ch for ch in punc_free if not ch.isdigit())
    normalized = " ".join(lemma.lemmatize(word) for word in number_free.split())
    normalized_v = " ".join(lemma.lemmatize(word, "v") for word in normalized.split())
    return normalized_v

# %%
data['stem_hm'] = [clean(senten) for senten in data["cleaned_hm"].tolist()]

# %%
content=list(map(lambda x:x.split(),data['stem_hm']))

# %%
from gensim import corpora, models
import gensim

# %%
dictionary = corpora.Dictionary(content)
corpus = [dictionary.doc2bow(text) for text in content]

# %%
ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics=15, id2word = dictionary, passes=20)

# %%
ldamodel.save('../output/lda20pass15topic.model')

# %%
import pyLDAvis.gensim
pyLDAvis.enable_notebook()
visualization = pyLDAvis.gensim.prepare(ldamodel, corpus, dictionary)

# %%
visualization
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 9     -0.214669 -0.074723       1        1  13.864615
# 5     -0.020724 -0.010318       2        1  13.766535
# 2     -0.130218  0.014889       3        1  12.814892
# 4     -0.036426  0.081085       4        1  10.745456
# 0     -0.145863 -0.065727       5        1  10.481055
# 6     -0.161304 -0.103870       6        1  10.248912
# 8      0.104643  0.151592       7        1   8.457768
# 1      0.171057  0.123510       8        1   6.789355
# 3      0.126597  0.216069       9        1   6.783134
# 7      0.306907 -0.332505      10        1   6.048275, topic_info=     Category          Freq        Term         Total  loglift  logprob
# term
# 264   Default  11356.000000        work  11356.000000  30.0000  30.0000
# 37    Default   9026.000000         new   9026.000000  29.0000  29.0000
# 10    Default  18114.000000       happy  18114.000000  28.0000  28.0000
# 36    Default  15340.000000        make  15340.000000  27.0000  27.0000
# 3     Default  14090.000000          go  14090.000000  26.0000  26.0000
# 35    Default   5067.000000        come   5067.000000  25.0000  25.0000
# 144   Default  10839.000000        time  10839.000000  24.0000  24.0000
# 18    Default  10133.000000      friend  10133.000000  23.0000  23.0000
# 55    Default   4963.000000       watch   4963.000000  22.0000  22.0000
# 189   Default   4563.000000        home   4563.000000  21.0000  21.0000
# 31    Default   6623.000000        last   6623.000000  20.0000  20.0000
# 312   Default   3711.000000         buy   3711.000000  19.0000  19.0000
# 120   Default   4122.000000      family   4122.000000  18.0000  18.0000
# 534   Default   4874.000000        find   4874.000000  17.0000  17.0000
# 58    Default   3207.000000        game   3207.000000  16.0000  16.0000
# 250   Default   3871.000000      dinner   3871.000000  15.0000  15.0000
# 104   Default   4320.000000        play   4320.000000  14.0000  14.0000
# 334   Default   3880.000000        life   3880.000000  13.0000  13.0000
# 33    Default   4785.000000       night   4785.000000  12.0000  12.0000
# 279   Default   3313.000000         eat   3313.000000  11.0000  11.0000
# 9     Default  20085.000000         get  20085.000000  10.0000  10.0000
# 364   Default   3540.000000       month   3540.000000   9.0000   9.0000
# 1402  Default   2779.000000       event   2779.000000   8.0000   8.0000
# 100   Default   2114.000000        help   2114.000000   7.0000   7.0000
# 985   Default   3544.000000        week   3544.000000   6.0000   6.0000
# 97    Default   2107.000000         car   2107.000000   5.0000   5.0000
# 146   Default   5308.000000        able   5308.000000   4.0000   4.0000
# 381   Default   2499.000000         dog   2499.000000   3.0000   3.0000
# 328   Default   2521.000000         job   2521.000000   2.0000   2.0000
# 24    Default   2604.000000        talk   2604.000000   1.0000   1.0000
# ...       ...           ...         ...           ...      ...      ...
# 86    Topic10    494.194641    positive    495.120605   2.8035  -4.7257
# 1210  Topic10    462.407684    pleasant    463.333679   2.8034  -4.7922
# 1759  Topic10    457.234802        mind    458.160980   2.8034  -4.8034
# 1251  Topic10    441.941559  compliment    442.867493   2.8033  -4.8375
# 437   Topic10    434.515198    exercise    435.441162   2.8033  -4.8544
# 544   Topic10    406.593048         joy    407.519012   2.8031  -4.9208
# 1341  Topic10    372.539764       group    373.466095   2.8029  -5.0083
# 2214  Topic10    361.257812         off    362.183838   2.8028  -5.0390
# 1384  Topic10    334.850342        joke    335.776337   2.8026  -5.1149
# 543   Topic10    316.756256        fill    317.682251   2.8025  -5.1705
# 1000  Topic10    316.330811      master    317.256775   2.8025  -5.1718
# 2382  Topic10    310.937836        till    311.864258   2.8024  -5.1890
# 2142  Topic10    298.693573    schedule    299.619537   2.8023  -5.2292
# 547   Topic10    297.007294      degree    297.933228   2.8023  -5.2349
# 320   Topic10    296.969482      series    297.895416   2.8023  -5.2350
# 2780  Topic10    285.523499      number    286.449585   2.8022  -5.2743
# 581   Topic10    276.890320        star    277.816315   2.8021  -5.3050
# 195   Topic10    274.615784        hike    275.541718   2.8020  -5.3133
# 1619  Topic10    266.242340     include    267.168365   2.8019  -5.3442
# 1712  Topic10    264.564240        bank    265.490234   2.8019  -5.3505
# 1577  Topic10    258.484619       might    259.410675   2.8018  -5.3738
# 55    Topic10   3170.213623       watch   4963.572266   2.3571  -2.8671
# 733   Topic10    654.303406       funny    918.125122   2.4666  -4.4451
# 1330  Topic10    413.085114        stay    634.549072   2.3761  -4.9050
# 287   Topic10    888.575012    favorite   3093.467285   1.5580  -4.1390
# 1744  Topic10    360.232330         air    533.374146   2.4129  -5.0419
# 1635  Topic10    435.577423        live   1011.507690   1.9629  -4.8520
# 378   Topic10    630.956848         one   5274.426758   0.6820  -4.4814
# 293   Topic10    335.001892        many   1231.757080   1.5033  -5.1145
# 925   Topic10    300.478119         use   1304.931274   1.3369  -5.2233
#
# [537 rows x 6 columns], token_table=      Topic      Freq         Term
# term
# 146       3  0.245446         able
# 146       5  0.189688         able
# 146       7  0.097764         able
# 146       8  0.362800         able
# 146       9  0.104357         able
# 119      10  0.998504       abroad
# 623       4  0.996680       accept
# 1714      3  0.995565   accomplish
# 398       3  0.999056          ago
# 1744      5  0.322475          air
# 1744     10  0.674948          air
# 1058      9  0.996950       amazon
# 1002      9  0.998590       amount
# 1592      7  0.996622    apartment
# 1274      8  0.997494  appointment
# 382       2  0.297014       around
# 382       5  0.643803       around
# 382       7  0.049774       around
# 382       8  0.008976       around
# 1445      6  0.998438       arrive
# 592       1  0.002455          ask
# 592       2  0.480265          ask
# 592       3  0.127634          ask
# 592       8  0.389448          ask
# 1543      4  0.999447       attend
# 2126      9  0.998028         aunt
# 265       3  0.996236        award
# 326       2  0.272353         back
# 326       4  0.122324         back
# 326       6  0.508477         back
# ...     ...       ...          ...
# 7         7  0.993809         with
# 68        2  0.207820      without
# 68        3  0.125203      without
# 68        5  0.292140      without
# 68        8  0.373905      without
# 420       2  0.996787        woman
# 264       4  0.999895         work
# 264       6  0.000088         work
# 493       3  0.997147      workout
# 91        2  0.998174        world
# 511       2  0.986349        would
# 511       4  0.013337        would
# 961       5  0.997170         yard
# 124       2  0.152704         year
# 124       3  0.054578         year
# 124       4  0.195379         year
# 124       5  0.122802         year
# 124       6  0.456659         year
# 124       8  0.012483         year
# 124       9  0.005516         year
# 49        1  0.199359    yesterday
# 49        3  0.175905    yesterday
# 49        4  0.108583    yesterday
# 49        5  0.214126    yesterday
# 49        6  0.129865    yesterday
# 49        7  0.028449    yesterday
# 49        9  0.143981    yesterday
# 260       6  0.995177      younger
# 1345      6  0.997755     youngest
# 1993      7  0.996876      youtube
#
# [792 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[10, 6, 3, 5, 1, 7, 9, 2, 4, 8])
